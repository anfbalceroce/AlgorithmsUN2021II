# %% [markdown]
# # Group 3
# ---
# **Numero de tabla:**
#
# $ 3 \ \text{mod} \ 4 = 3 $
#
# Por lo tanto, se desarollara la tabla numero 3.

# %% [markdown]
# # 3. (1 noneosecond by instruction)
#
# Asuuming that you can execute a 1000 million instructions $10^9$ every second, i.e. each instrcution takes 1  nanosecond, 1 $\eta s  = 10^{-9} s$. If you have alog_2orithms take $\bf{ Time\ Complexity}$ steps to solve a poblem of size $n$ as specified in column one. What is the size of the largest porblem that you can solve in the time specified in row one?
# <br>
#
# $$
# \begin{array}{|c|c|c|c|c|c|c|c|}
#  \hline
#  \bf{ Time\ Complexity} & Second  & Minute  & Hour & Day & Year & Century & Mileniun  \\
#   \hline\\
# \log_2(n) &  2 ^ {10^9}  & 2 ^ {60 \cdot 10^9}  & 2 ^ {36 \cdot 10^{11}} & 2 ^ {8.64 \cdot 10^{13}} & 2 ^ {3.15 \cdot 10^{16}} & 2 ^ {3.15 \cdot 10^{18}} & 2 ^ {3.15 \cdot 10^{19}} \\
#    \hline\\
# \log_2^2(n) &  2 ^ {\sqrt{10^9}}  & 2 ^ {\sqrt{60 \cdot 10^9}}  & 2 ^ {\sqrt{36 \cdot 10^{11}}} & 2 ^ {\sqrt{8.64 \cdot 10^{13}}} & 2 ^ {\sqrt{3.15 \cdot 10^{16}}} & 2 ^ {\sqrt{3.15 \cdot 10^{18}}} & 2 ^ {\sqrt{3.15 \cdot 10^{19}}} \\
#    \hline\\
# \sqrt{n} &  10^{18}  & {3.6 \cdot 10^{21}}  & {1.296 \cdot 10^{25}} & {7.465 \cdot 10^{27}} & {9.948 \cdot 10^{32}} & {9.948 \cdot 10^{36}} & {9.948 \cdot 10^{38}} \\
#  \hline\\
#  n &  10^{9}  & 60 \cdot 10^{9}  & 3600 \cdot 10^{9} & 8.64 \cdot 10^{13} & 3.154  \cdot 10^{16} & 3.154  \cdot 10^{18} & 3.154  \cdot 10^{19} \\
#  \hline\\
#  n\log_2(n) &  3.962 \cdot 10^{9}  & 1.944 \cdot 10^{9}  & 9.857 \cdot 10^{10} & 2.110 \cdot 10^{12} & 6.412 \cdot 10^{14} & 5.667 \cdot 10^{16} & 5.355 \cdot 10^{17} \\
#  \hline\\
#  n^2 & 3.162 \cdot 10^{4} & 2.449 \cdot 10^{5} & 1.897 \cdot 10^{6} & 9.295 \cdot 10^{6} & 1.776 \cdot 10^{8} & 1.776 \cdot 10^{9} & 5.616 \cdot 10^{9} \\
#  \hline\\
#   n^3 & 1 \cdot 10^{3} & 3.915 \cdot 10^{3} & 1.533 \cdot 10^{4} & 4.421 \cdot 10^{4} & 3.160 \cdot 10^{5} & 1.467 \cdot 10^{6} & 3.160 \cdot 10^{6} \\
#  \hline\\
#   n^4 & 1.778 \cdot 10^{2} & 4.949 \cdot 10^{2} & 1.377 \cdot 10^{3} & 3.049 \cdot 10^{3} & 1.333 \cdot 10^{4} & 4.214 \cdot 10^{4} & 7.494 \cdot 10^{4} \\
#  \hline\\
#   2^n & 29 & 35 & 41 & 46 & 54 & 61 & 64 \\
#  \hline\\
#  n! & 12 & 13 & 15 & 16 & 18 & 20 & 20 \\
#  \hline\\
#  n^n & 9 & 10 & 11 & 12 & 14 & 15 & 16 \\
#  \hline
# \end{array}
# $$

# %%
import math
# 1. One microsecond by Instructionmath.sqrt(60*10**6)

# %% [markdown]
# ### Calculating the final results by mathematical approximations:
#
# #### 1.  $n\ \log_2(n)$:
#
# First, we will take the Lambert W-Function, which is defined as follows:
#
# \begin{align*}
#     f(x) = x e^x \ \Rightarrow \ f^{-1}(x) = W(x)
# \end{align*}
# <br>
#
# That done, we can calculate the inverse of $n\ \log_2(n)$ as follows:
#
# \begin{align*}
#    t &= n \cdot \log_2(n) \\[2mm]
#    n &= \frac{t\ln(2)}{W(t\ln(2))}
# \end{align*}
# <br>
#
# #### 2.  $n!$:
#
# We can use the Gamma function to calculate the factorial of any complex number:
#
# \begin{align*}
#    \Gamma &(n + 1) = n!\\[2mm]
#    \Gamma &(z) = \int_0^{\infty} t^{z - 1} \ e^{-z} dt
# \end{align*}
# <br>
#
# Once the function is defined, we proceed to calculate a function that can approximate the inverse of the Gamma function.
#
# This is possible thanks to the following function:
#
# First, we take the first real root of the DiGamma function, which has a value of approximately $k = 1.461632145$
#
# Second, we define a value $c$ which will be a function of the constant $k$ defined above, this constant $c$ has the following form:
#
# \begin{align*}
#     c = \frac{\sqrt{2\pi}}{e} - \Gamma(k)
# \end{align*}
# <br>
#
# Third, we define a new function called $L(x)$ which will have the following form:
#
# \begin{align*}
#     L(x) = \ln\left( \frac{x + c}{\sqrt{2\pi}}\right)
# \end{align*}
# <br>
#
# And finally, the approximation of the inverse Gamma function can be represented in the following way:
#
# \begin{align*}
#     \Gamma^{-1}(x) \approx \frac{L(x)}{W\left( \frac{L(x)}{e} \right)} + \frac{1}{2}
# \end{align*}
# <br>
#
# With this, we can calculate the inverse of $n!$ in this way:
#
# \begin{align*}
#     t &= n!\\[2mm]
#     n &= \frac{L(t)}{W\left( \frac{L(t)}{e} \right)} + \frac{1}{2} - 1
# \end{align*}
# <br>
#
# #### 3.  $n^n$:
#
# Having defined Lambert W-Function, the inverse function of $n^n$ can be obtained as follows:
#
# \begin{align*}
#     t &= n^n\\[2mm]
#     n &= \frac{\ln(t)}{W(\ln(t))}
# \end{align*}
# <br>

# %%
# Importing the necesary libraries

from scipy.special import *
import numpy as np
import math

# Function to print in scientific notation:

def print_sci(num: float) -> None:
    scientific_notation = "{:.3e}".format(num)
    print(scientific_notation)

# %% [markdown]
# #### 1.  $n\ \log_2(n)$:

# %%
# Inverse n log_2(n):

def inverse_nlog2n(t: "time") -> float:
    total = t * 10 ** 9
    return (total * math.log(2)) / lambertw(total * math.log(2)).real

# Calculating n:

print_sci(inverse_nlog2n(1))            # Second
print_sci(inverse_nlog2n(60))           # Minute
print_sci(inverse_nlog2n(3600))         # Hour
print_sci(inverse_nlog2n(86400))        # Day
print_sci(inverse_nlog2n(3.154e+7))     # Year
print_sci(inverse_nlog2n(3.154e+9))     # Century
print_sci(inverse_nlog2n(3.154e+10))    # Millenium
# Out:
# 3.962e+07
# 1.944e+09
# 9.857e+10
# 2.110e+12
# 6.412e+14
# 5.667e+16
# 5.355e+17

# %% [markdown]
# #### 2.  $n!$:

# %%
# Inverse n!:

def inverse_factorial(t: "time") -> float:
    total = t * 10 ** 9

    k = 1.46163214496836234126265954233

    c = (np.sqrt(2 * np.pi) / np.e) - math.gamma(k)

    def el(x: float) -> float:
        return math.log((x + c) / (np.sqrt(2 * np.pi)))
    
    return ((el(total)) / (lambertw(el(total) / np.e)).real + 0.5 - 1)

# Calculating n:

print(math.floor(inverse_factorial(1)))            # Second
print(math.floor(inverse_factorial(60)))           # Minute
print(math.floor(inverse_factorial(3600)))         # Hour
print(math.floor(inverse_factorial(86400)))        # Day
print(math.floor(inverse_factorial(3.154e+7)))     # Year
print(math.floor(inverse_factorial(3.154e+9)))     # Century
print(math.floor(inverse_factorial(3.154e+10)))    # Millenium
# Out:
# 12
# 13
# 15
# 16
# 18
# 20
# 20

# %% [markdown]
# #### 3.  $n^n$:

# %%
# Inverse n^n:

def inverse_n_n(t: "time") -> float:
    total = t * 10 ** 9
    return math.log(total) / lambertw(math.log(total)).real

# Calculating n:

print(math.floor(inverse_n_n(1)))            # Second
print(math.floor(inverse_n_n(60)))           # Minute
print(math.floor(inverse_n_n(3600)))         # Hour
print(math.floor(inverse_n_n(86400)))        # Day
print(math.floor(inverse_n_n(3.154e+7)))     # Year
print(math.floor(inverse_n_n(3.154e+9)))     # Century
print(math.floor(inverse_n_n(3.154e+10)))    # Millenium
# Out:
# 9
# 10
# 11
# 12
# 14
# 15
# 16

# %% [markdown]
# ### Time complexity $log_2(n)$
#
# Second
# $$ \log_2(n) \cdot 10^{-9}\ s\le 1\ s$$
# $$ \log_2(n) \le 1 \cdot 10^{9}$$
# $$ 2^{\log_2(n)} \le 2^{10^{9}}$$
# $$ n \le 2 ^ {10^9}$$
#
# Minute
# $$ \log_2(n) \cdot 10^{-9} \ s \le 60\ s$$
# $$ \log_2(n) \le 60 \cdot 10^{9} $$
# $$ 2^{\log_2(n)} \le 2 ^ {60 \cdot 10^9}$$
# $$ n \le 2 ^ {60 \cdot 10^9}$$
#
# Hour
# $$ \log_2(n) \cdot 10^{-9} \ s \le 3600\ s$$
# $$ \log_2(n) \le 3600 \cdot 10^{9} $$
# $$ 2^{\log_2(n)} \le 2 ^ {36 \cdot 10^{11}}$$
# $$ n \le 2 ^ {36 \cdot 10^{11}}$$
#
# Day
# $$ \log_2(n) \cdot 10^{-9} \ s \le 86400\ s$$
# $$ \log_2(n) \le 86400\cdot 10^{9} $$
# $$ 2^{\log_2(n)} \le 2 ^ {8.64 \cdot 10^{13}}$$
# $$ n \le 2 ^ {8.64 \cdot 10^{13}}$$
#
# Year
# $$ \log_2(n) \cdot 10^{-9} \ s \le 31536000\ s$$
# $$ \log_2(n) \le 31536000\cdot 10^{9} $$
# $$ 2^{\log_2(n)} \le 2 ^ {3.15 \cdot 10^{16}}$$
# $$ n \le 2 ^ {3.15 \cdot 10^{16}}$$
#
# Century
# $$ \log_2(n) \cdot 10^{-9} \ s \le 3153600000\ s$$
# $$ \log_2(n) \le 3153600000\cdot 10^{9} $$
# $$ 2^{\log_2(n)} \le 2 ^ {3.15 \cdot 10^{18}}$$
# $$ n \le 2 ^ {3.15 \cdot 10^{18}}$$
#
# Millennium
# $$ \log_2(n) \cdot 10^{-9} \ s \le 3153600000000\ s$$
# $$ \log_2(n) \le 3153600000000\cdot 10^{9} $$
# $$ 2^{\log_2(n)} \le 2 ^ {3.15 \cdot 10^{19}}$$
# $$ n \le 2 ^ {3.15 \cdot 10^{19}}$$
#
# <br>

# %% [markdown]
# ### Time complexity $log_2^2(n)$
#
# Second
# $$ \log_2^2(n) \cdot 10^{-9} \ s\le 1\ s$$
# $$ \log_2(n) \le \sqrt{1 \cdot 10^{9} }$$
# $$ 2^{\log_2(n)} \le 2 ^ {\sqrt{10^9}}$$
# $$ n \le 2 ^ {\sqrt{10^9}}$$
#
# Minute
# $$ \log_2^2(n) \cdot 10^{-9} \ s \le 60\ s$$
# $$ \log_2(n) \le \sqrt{60 \cdot 10^{9} }$$
# $$ 2^{\log_2(n)} \le 2 ^ {\sqrt{60 \cdot 10^9}}$$
# $$ n \le 2 ^ {\sqrt{60 \cdot 10^9}}$$
#
# Hour
# $$ \log_2^2(n) \cdot 10^{-9} \ s \le 3600\ s$$
# $$ \log_2(n) \le \sqrt{3600 \cdot 10^{9} }$$
# $$ 2^{\log_2(n)} \le 2^{\sqrt{3.6 \cdot 10^{9}}}$$
# $$ n \le  2^{\sqrt{3.6 \cdot 10^{9}}}$$
#
# Day
# $$ \log_2^2(n) \cdot 10^{-9} \ s \le 86400\ s$$
# $$ \log_2(n) \le \sqrt{86400\cdot 10^{9} }$$
# $$ 2^{\log_2(n)} \le 2 ^ {\sqrt{8.64 \cdot 10^{13}}}$$
# $$ n \le 2 ^ {\sqrt{8.64 \cdot 10^{13}}}$$
#
# Year
# $$ \log_2^2(n) \cdot 10^{-9} \ s \le 31536000\ s$$
# $$ \log_2(n) \le \sqrt{31536000\cdot 10^{9} }$$
# $$ 2^{\log_2(n)} \le 2 ^ {\sqrt{3.15 \cdot 10^{16}}}$$
# $$ n \le 2 ^ {\sqrt{3.15 \cdot 10^{16}}}$$
#
# Century
# $$ \log_2^2(n) \cdot 10^{-9} \ s \le 3153600000\ s$$
# $$ \log_2(n) \le \sqrt{3153600000\cdot 10^{9} }$$
# $$ 2^{\log_2(n)} \le 2 ^ {\sqrt{3.15 \cdot 10^{18}}}$$
# $$ n \le 2 ^ {\sqrt{3.15 \cdot 10^{18}}}$$
#
# Millennium
# $$ \log_2^2(n) \cdot 10^{-9} \ s \le 3153600000000\ s$$
# $$ \log_2(n) \le \sqrt{3153600000000\cdot 10^{9} }$$
# $$ 2^{\log_2(n)} \le 2 ^ {\sqrt{3.15 \cdot 10^{19}}}$$
# $$ n \le 2 ^ {\sqrt{3.15 \cdot 10^{19}}}$$
#
# <br>

# %% [markdown]
# ### Time complexity $\sqrt{n}$
#
# Second
# $$  \sqrt{n}  \cdot 10^{-9} \ s\le 1\ s$$
# $$  \sqrt{n}  \le 10^{9}  $$
# $$  n \le   10^{18}$$
#
# Minute
# $$  \sqrt{n} \cdot 10^{-9} \ s\le 60\ s$$
# $$  \sqrt{n}  \le 60 \cdot 10^{9} $$
# $$  n \le {3.6 \cdot 10^{21}}$$
#
# Hour
# $$  \sqrt{n}\cdot 10^{-9} \ s\le 3600\ s$$
# $$  \sqrt{n} \le 3600 \cdot 10^{9}$$
# $$  n  \le {1.296 \cdot 10^{25}}$$
#
# Day
# $$  \sqrt{n} \cdot 10^{-9} \ s\le 84600\ s$$
# $$  \sqrt{n}\le 84600 \cdot 10^{9} $$
# $$  n \le {7.465 \cdot 10^{27}}$$
#
# Year
# $$  \sqrt{n} \cdot 10^{-9} \ s\le 31536000\ s$$
# $$  \sqrt{n} \le 31536000 \cdot 10^{9} $$
# $$  n \le {9.948 \cdot 10^{32}}$$
#
# Century
# $$  \sqrt{n} \cdot 10^{-9} \ s\le 3153600000\ s$$
# $$  \sqrt{n} \le 3153600000 \cdot 10^{9} $$
# $$  n \le {9.948 \cdot 10^{36}}$$
#
# Millennium
# $$  \sqrt{n} \cdot 10^{-9} \ s\le 3153600000000\ s$$
# $$  \sqrt{n} \le 3153600000000 \cdot 10^{9} $$
# $$  n \le {9.948 \cdot 10^{38}}$$
#
# <br>

# %% [markdown]
# ### Time complexity $n$
#
# Second
# $$  n  \cdot 10^{-9} \ s\le 1\ s$$
# $$  n \le  10^{9} $$
#
# Minute
# $$  n \cdot 10^{-9} \ s\le 60\ s$$
# $$  n \le 60 \cdot 10^{9} $$
#
# Hour
# $$  n \cdot 10^{-9} \ s\le 3600\ s$$
# $$  n \le 3600 \cdot 10^{9}  $$
#
# Day
# $$  n \cdot 10^{-9} \ s\le 84600\ s$$
# $$  n \le 84600 \cdot 10^{9}  $$
#
# Year
# $$  n \cdot 10^{-9} \ s\le 31536000\ s$$
# $$  n \le 31536000 \cdot 10^{9}  $$
#
# Century
# $$  n \cdot 10^{-9} \ s\le 3153600000\ s$$
# $$  n \le 3153600000 \cdot 10^{9}$$
#
# Millennium
# $$  n \cdot 10^{-9} \ s\le 3153600000000\ s$$
# $$  n \le 3153600000000 \cdot 10^{9}$$
#
# <br>

# %% [markdown]
# ### Time complexity $n \log_2(n)$
#
# Second
# $$   n\log_2{n}  \cdot 10^{-9} \ s\le 1\ s$$
# $$   n\log_2{n} \le  10^{9} $$
# $$   n \le \frac{10^{9}\ln(2)}{W(10^{9}\ln(2))}$$
#
# Minute
# $$   n\log_2{n} \cdot 10^{-9} \ s\le 60\ s$$
# $$   n\log_2{n} \le 60 \cdot 10^{9} $$
# $$   n \le 1.944 \cdot 10^{9}$$
#
# Hour
# $$   n\log_2{n} \cdot 10^{-9} \ s\le 3600\ s$$
# $$   n\log_2{n} \le 3600 \cdot 10^{9} $$
# $$   n \le 9.857 \cdot 10^{10}$$
#
# Day
# $$   n\log_2{n} \cdot 10^{-9} \ s\le 84600\ s$$
# $$   n\log_2{n} \le 84600 \cdot 10^{9} $$
# $$   n \le 2.110 \cdot 10^{12}$$
#
# Year
# $$   n\log_2{n} \cdot 10^{-9} \ s\le 31536000\ s$$
# $$   n\log_2{n} \le 31536000 \cdot 10^{9} $$
# $$   n \le 6.412 \cdot 10^{14}$$
#
# Century
# $$   n\log_2{n} \cdot 10^{-9} \ s\le 3153600000\ s$$
# $$   n\log_2{n} \le 3153600000 \cdot 10^{9} $$
# $$   n \le 5.667 \cdot 10^{16}$$
#
# Millennium
# $$   n\log_2{n} \cdot 10^{-9} \ s\le 3153600000000\ s$$
# $$   n \le 3153600000000 \cdot 10^{9} $$
# $$   n \le 5.355 \cdot 10^{17}$$
#
# <br>

# %% [markdown]
# ### Time complexity $n^2$
#
# Second
# $$  n^2 \cdot 10^{-9} \ s\le 1\ s$$
# $$  n^2 \le  10^{9} $$
# $$ \sqrt{n^2} \le \sqrt{10^{9} }$$
# $$ n \le 3.162 \cdot 10^{4} $$
#
# Minute
# $$  n^2\cdot 10^{-9} \ s\le 60\ s$$
# $$  n^2 \le 60 \cdot 10^{9} $$
# $$ \sqrt{n^2} \le \sqrt{60 \cdot10^{9} }$$
# $$ n \le 2.449 \cdot 10^{5} $$
#
# Hour
# $$  n^2 \cdot 10^{-9} \ s\le 3600\ s$$
# $$ n^2 \le 3600 \cdot 10^{9} $$
# $$ \sqrt{n^2} \le \sqrt{36 \cdot10^{11}}$$
# $$ n \le 1.897 \cdot 10^{6}$$
#
# Day
# $$  n^2 \cdot 10^{-9} \ s\le 84600\ s$$
# $$  n^2 \le 84600 \cdot 10^{9} $$
# $$ \sqrt{n^2} \le \sqrt{8.46 \cdot10^{13}}$$
# $$ n \le 9.295 \cdot 10^{6}$$
#
# Year
# $$  n^2 \cdot 10^{-9} \ s\le 31536000\ s$$
# $$  n^2 \le 31536000 \cdot 10^{9} $$
# $$ \sqrt{n^2} \le \sqrt{3.1536 \cdot10^{16}}$$
# $$ n \le 1.776 \cdot 10^{8}$$
#
# Century
# $$  n^2 \cdot 10^{-9} \ s\le 3153600000\ s$$
# $$  n^2 \le 3153600000 \cdot 10^{9} $$
# $$ \sqrt{n^2} \le \sqrt{3.1536 \cdot10^{18}}$$
# $$ n \le 1.776 \cdot 10^{9}$$
#
# Millennium
# $$  n^2 \cdot 10^{-9} \ s\le 3153600000000\ s$$
# $$ n^2 \le 3153600000000 \cdot 10^{9} $$
# $$ \sqrt{n^2} \le \sqrt{3.1536 \cdot10^{19}}$$
# $$ n \le 5.616 \cdot 10^{9} $$
#
# <br>

# %% [markdown]
# ### Time complexity $n^3$
#
# Second
# $$  n^3 \cdot 10^{-9} \ s\le 1\ s$$
# $$  n^3 \le  10^{9} $$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{10^{9} }$$
# $$ n \le  1 \cdot 10^{3} $$
#
# Minute
# $$  n^3 \cdot 10^{-9} \ s\le 60\ s$$
# $$  n^3 \le 60 \cdot 10^{9} $$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{60 \cdot10^{9} }$$
# $$ n \le  3.915 \cdot 10^{3} $$
#
# Hour
# $$  n^3 \cdot 10^{-9} \ s\le 3600\ s$$
# $$  n^3 \le 3600 \cdot 10^{9} $$
# $$ \sqrt[3]{n^3 } \le \sqrt[3]{36 \cdot10^{11}}$$
# $$ n \le 1.533 \cdot 10^{4} $$
#
# Day
# $$  n^3 \cdot 10^{-9} \ s\le 84600\ s$$
# $$  n^3 \le 84600 \cdot 10^{9} $$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{8.46 \cdot10^{13}}$$
# $$ n \le 4.421 \cdot 10^{4} $$
#
# Year
# $$  n^3 \cdot 10^{-9} \ s\le 31536000\ s$$
# $$  n^3 \le 31536000 \cdot 10^{9} $$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{3.1536 \cdot10^{16}}$$
# $$ n \le 3.160 \cdot 10^{5} $$
#
# Century
# $$  n^3 \cdot 10^{-9} \ s\le 3153600000\ s$$
# $$  n^3 \le 3153600000 \cdot 10^{9} $$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{3.1536 \cdot10^{18}}$$
# $$ n \le 1.467 \cdot 10^{6} $$
#
# Millennium
# $$  n^3 \cdot 10^{-9} \ s\le 3153600000000\ s$$
# $$  n^3 \le 3153600000000 \cdot 10^{9} $$
# $$ \sqrt[3]{n^3} \le \sqrt[3]{3.1536 \cdot10^{19}}$$
# $$ n \le 3.160 \cdot 10^{6} $$
#
# <br>

# %% [markdown]
# ### Time complexity $n^4$
#
# Second
# $$  n^4 \cdot 10^{-9} \ s\le 1\ s$$
# $$  n^4\le  10^{9} $$
# $$ \sqrt[4]{n^4 } \le \sqrt[4]{10^{9} }$$
# $$ n \le 1.778 \cdot 10^{2}$$
#
# Minute
# $$  n^4 \cdot 10^{-9} \ s\le 60\ s$$
# $$  n^4 \le 60 \cdot 10^{9} $$
# $$ \sqrt[4]{n^4 } \le \sqrt[4]{60 \cdot10^{9}}$$
# $$ n \le 4.949 \cdot 10^{2}$$
#
# Hour
# $$  n^4 \cdot 10^{-9} \ s\le 3600\ s$$
# $$  n^4 \le 3600 \cdot 10^{9} $$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{36 \cdot10^{11}}$$
# $$ n \le 1.377 \cdot 10^{3} $$
#
# Day
# $$  n^4 \cdot 10^{-9} \ s\le 84600\ s$$
# $$  n^4 \le 84600 \cdot 10^{9} $$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{8.46 \cdot10^{13}}$$
# $$ n \le 3.049 \cdot 10^{3} $$
#
# Year
# $$  n^4 \cdot 10^{-9} \ s\le 31536000\ s$$
# $$  n^4 \le 31536000 \cdot 10^{9} $$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{3.1536 \cdot10^{16}}$$
# $$ n \le 1.333 \cdot 10^{4} $$
#
# Century
# $$  n^4 \cdot 10^{-9} \ s\le 3153600000\ s$$
# $$  n^4 \le 3153600000 \cdot 10^{9} $$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{3.1536 \cdot10^{18}}$$
# $$ n \le 4.214 \cdot 10^{4} $$
#
# Millennium
# $$  n^4 \cdot 10^{-9} \ s\le 3153600000000\ s$$
# $$  n^4 \le 3153600000000 \cdot 10^{9} $$
# $$ \sqrt[4]{n^4} \le \sqrt[4]{3.1536 \cdot10^{19}}$$
# $$ n \le 7.494 \cdot 10^{4} $$
#
# <br>

# %% [markdown]
# ### Time complexity $2^n$
#
# Second
# $$  2^n  \cdot 10^{-9} \ s\le 1\ s$$
# $$  2^n \le  10^{9} $$
# $$  \log_2(2^n) \le  \log_2(10^{9} )$$
# $$  n \le 29.897 $$
#
# Minute
# $$  2^n  \cdot 10^{-9} s \le 60\ s$$
# $$  2^n \le   60 \cdot  10^{9} $$
# $$  \log_2(2^n) \le  \log_2(60 \cdot  10^{9} )$$
# $$  n \le 35.804 $$
#
# Hour
# $$  2^n  \cdot 10^{-9} s \le 3600\ s$$
# $$  2^n \le   3600 \cdot  10^{9} $$
# $$  \log_2(2^n) \le  \log_2(36 \cdot  10^{11})$$
# $$  n \le 41.711 $$
#
# Day
# $$  2^n  \cdot 10^{-9} s \le  84600\ s$$
# $$  2^n \le    84600\cdot  10^{9} $$
# $$  \log_2(2^n) \le  \log_2( 8.46 \cdot  10^{13})$$
# $$  n \le 46.296 $$
#
# Year
# $$  2^n  \cdot 10^{-9} s \le  31536000\ s$$
# $$  2^n \le    31536000\cdot  10^{9} $$
# $$  \log_2(2^n) \le  \log_2( 3.1536 \cdot  10^{16})$$
# $$  n \le 54.808 $$
#
# Century
# $$  2^n  \cdot 10^{-9} s \le  3153600000\ s$$
# $$  2^n \le    3153600000\cdot  10^{9} $$
# $$  \log_2(2^n) \le  \log_2( 3.1536 \cdot  10^{18})$$
# $$  n \le 61.452 $$
#
# Millennium
# $$  2^n  \cdot 10^{-9} s \le  3153600000000\ s$$
# $$  2^n \le    3153600000000\cdot  10^{9} $$
# $$  \log_2(2^n) \le  \log_2( 3.1536 \cdot  10^{19})$$
# $$  n \le 64.774 $$
#
# <br>

# %% [markdown]
# ### Time complexity $n!$
#
# Second
# $$  n!  \cdot 10^{-9} \ s\le 1\ s$$
# $$  n! \le  10^{9} $$
# $$  n \le \frac{L(10^{9})}{W\left( \frac{L(10^{9})}{e} \right)} + \frac{1}{2} - 1$$
# $$  n \lesssim  12.289 $$
#
# Minute
# $$  n! \cdot 10^{-9} \ s\le 60\ s$$
# $$  n! \le 60 \cdot 10^{9} $$
# $$  n \lesssim  13.859 $$
#
# Hour
# $$  n! \cdot 10^{-9} \ s\le 3600\ s$$
# $$  n! \le 3600 \cdot 10^{9}  $$
# $$  n \lesssim 15.367 $$
#
# Day
# $$  n! \cdot 10^{-9} \ s\le 84600\ s$$
# $$  n! \le 84600 \cdot 10^{9}  $$
# $$  n \lesssim 16.502 $$
#
# Year
# $$  n! \cdot 10^{-9} \ s\le 31536000\ s$$
# $$  n! \le 31536000 \cdot 10^{9}   $$
# $$  n \lesssim 18.543 $$
#
# Century
# $$  n! \cdot 10^{-9} \ s\le 3153600000\ s$$
# $$  n! \le 3153600000 \cdot 10^{9}  $$
# $$  n \lesssim 20.085 $$
#
# Millennium
# $$  n! \cdot 10^{-9} \ s\le 3153600000000\ s$$
# $$  n! \le 3153600000000 \cdot 10^{9}  $$
# $$  n \lesssim 20.842 $$
#
# <br>

# %% [markdown]
# ### Time complexity $n^n$
#
# Second
# $$  n^n  \cdot 10^{-9} \ s\le 1\ s$$
# $$  n^n \le  10^{9} $$
# $$  n^n \le  \frac{\ln(10^{9})}{W(\ln(10^{9}))} $$
# $$  n \lesssim 9.295 $$
#
# Minute
# $$  n^n \cdot 10^{-9} \ s\le 60\ s$$
# $$  n^n \le 60 \cdot 10^{9} $$
# $$  n \lesssim 10.538 $$
#
# Hour
# $$  n^n \cdot 10^{-9} \ s\le 3600\ s$$
# $$  n^n \le 3600 \cdot 10^{9}$$
# $$  n \lesssim 11.739 $$
#
# Day
# $$  n^n \cdot 10^{-9} \ s\le 84600\ s$$
# $$  n^n \le 84600 \cdot 10^{9} $$
# $$  n \lesssim 12.647 $$
#
# Year
# $$  n^n \cdot 10^{-9} \ s\le 31536000\ s$$
# $$  n^n \le 31536000 \cdot 10^{9} $$
# $$  n \lesssim 14.286 $$
#
# Century
# $$  n^n \cdot 10^{-9} \ s\le 3153600000\ s$$
# $$  n^n \le 3153600000 \cdot 10^{9} $$
# $$  n \lesssim 15.530 $$
#
# Millennium
# $$  n^n \cdot 10^{-9} \ s\le 3153600000000\ s$$
# $$  n^n \le 3153600000000 \cdot 10^{9} $$
# $$  n \lesssim 16.142 $$
#
# <br>
