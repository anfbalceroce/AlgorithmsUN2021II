# %% [markdown]
# #Binary Search

# %%
def binary_search(keys, query):
    # write your code here
    low = 0
    high = len(keys) - 1

    while low <= high:
        mid = (low + high) //2
        if keys[mid] == query:
            return mid
        elif keys[mid] < query:
            low = mid + 1
        else:
            high = mid - 1
    return -1

        

if __name__ == '__main__':
    num_keys = int(input())
    input_keys = list(map(int, input().split()))
    assert len(input_keys) == num_keys

    num_queries = int(input())
    input_queries = list(map(int, input().split()))
    assert len(input_queries) == num_queries

    for q in input_queries:
        print(binary_search(input_keys, q), end=' ')

# %% [markdown]
# #Binary Search with Duplicates

# %%
def binary_search(keys, query):
    # write your code here
    low = 0
    high = len(keys) - 1
    result = -1

    while low <= high:
        mid = (low + high) //2
        if keys[mid] == query:
            result = mid
            high = mid - 1
        elif keys[mid] < query:
            low = mid + 1
        else:
            high = mid - 1
    return result


if __name__ == '__main__':
    num_keys = int(input())
    input_keys = list(map(int, input().split()))
    assert len(input_keys) == num_keys

    num_queries = int(input())
    input_queries = list(map(int, input().split()))
    assert len(input_queries) == num_queries

    for q in input_queries:
        print(binary_search(input_keys, q), end=' ')

# %% [markdown]
# #Majority Element

# %%
import sys

def get_majority_element(seq, l, r):
    if l+1==r:
        return seq[l]
    elif l+2==r:
        return seq[l]
    m = (l+r)//2
    left = get_majority_element(seq, l, m)
    right = get_majority_element(seq, m, r)

    c1, c2 = 0, 0
    for i in seq[l:r]:
        if i == left:
            c1+=1
        elif i == right:
            c2+=1
    if c1>(r-l)//2 and left != -1:
        return left
    elif c2>(r-l)//2 and right != -1:
        return right
    else: 
        return -1

if __name__ == '__main__':
    input = sys.stdin.read()
    n, *a = list(map(int, input.split()))
    if get_majority_element(a, 0, n) != -1:
        print(1)
    else:
        print(0)

# %% [markdown]
# #Summit Screenshots:
# ## Camilo
# ![Screenshot](https://pomf2.lain.la/f/3qekhm39.png)

# %% [markdown]
# ## Andres:
#
# ![Screenshot](https://files.catbox.moe/f9cgjd.png)

# %% [markdown]
# ## Gabriel:
#
# ![Week4.jpg](data:image/jpeg;base64,...)
